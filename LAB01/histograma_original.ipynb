# %%
import cv2
import numpy as np

from glob import glob
import os
from os.path import join
import pandas as pd

# %%
CORREL_ACC = 0.85
CHISQR_ACC = 2500
INTERSECT_ACC = 600
BHATTACHARYYA_ACC = 0.3

# %%
def list_images():
    cwd = os.getcwd()
    
    files = []
    for ext in ('*.jpg', '*.png'):
        #files.extend(glob(join(cwd, ext)))
        files.extend(glob(ext))
    
    return files

# %%
def get_class(parse):
    str_list = []

    str_list = parse.split('1')
    str_list = str_list[0].split('2')

    return str_list[0]

# %%
def verify_hit(class_1, class_2, value, acceptance, higher):
    if (higher == True):
        if ( (value >= acceptance) and (class_1 == class_2) ):
            return 1
        else:
            return 0
    elif (higher == False):
        if ( (value <= acceptance) and (class_1 == class_2) ):
            return 1
        else:
            return 0

# %%
files = list_images()
files
# Out:
# ['hulk1.png',
#  'hulk2.png',
#  'iron1.png',
#  'iron2.png',
#  'k3po1.png',
#  'k3po2.png',
#  'magneto1.png',
#  'magneto2.png',
#  'trooper1.png',
#  'trooper2.png',
#  'vader1.png',
#  'vader2.png',
#  'volve1.png',
#  'volve2.png']

# %%
img1 = cv2.imread(files[0])
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

img2 = cv2.imread(files[1])
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

result = []
hist1 = cv2.calcHist([img1], [0,1,2], None, [8,8,8], [0, 256, 0, 256, 0, 256])
hist2 = cv2.calcHist([img2], [0,1,2], None, [8,8,8], [0, 256, 0, 256, 0, 256])
cv2.normalize(hist1, hist1, 0, 255, cv2.NORM_MINMAX)
cv2.normalize(hist2, hist2, 0, 255, cv2.NORM_MINMAX)
sc = cv2.compareHist(hist1, hist2, cv2.HISTCMP_BHATTACHARYYA)
print(sc)

# %%
img1 = cv2.imread(files[0])
img2 = cv2.imread(files[1])
result = []
for ch, col in enumerate(['b', 'g', 'r']):
    hist1 = cv2.calcHist([img1], [ch], None, [256], [0,255])
    hist2 = cv2.calcHist([img2], [ch], None, [256], [0,255])
    cv2.normalize(hist1, hist1, 0, 255, cv2.NORM_MINMAX)
    cv2.normalize(hist2, hist2, 0, 255, cv2.NORM_MINMAX)
    sc = cv2.compareHist(hist1, hist2, cv2.HISTCMP_CORREL)
    result.append(sc)
print(max(result))

# %%
img1 = cv2.imread(files[0],0)
img2 = cv2.imread(files[0],0)

for ch, col in enumerate(['b', 'g', 'r']):
    hist1 = cv2.calcHist([img1], [0], None, [256], [0,255])
    hist2 = cv2.calcHist([img2], [0], None, [256], [0,255])
    cv2.normalize(hist1, hist1, 0, 255, cv2.NORM_MINMAX)
    cv2.normalize(hist2, hist2, 0, 255, cv2.NORM_MINMAX)
    sc = cv2.compareHist(hist1, hist2, cv2.HISTCMP_BHATTACHARYYA)
    print(sc)

# %%
# cv2.HISTCMP_CORREL
# cv2.HISTCMP_CHISQR
# cv2.HISTCMP_INTERSECT
# cv2.HISTCMP_BHATTACHARYYA

# CORREL_ACC = 0.8
# CHISQR_ACC = 3000
# INTERSECT_ACC = 500
# BHATTACHARYYA_ACC = 0.3

# %%
# IMAGENS COLORIDAS

df = pd.DataFrame()
for i in range(0,len(files),1):
    temporary = []
    
    selected_image = cv2.imread(files[i])
    selected_image = cv2.cvtColor(selected_image, cv2.COLOR_BGR2RGB)
    selected_image_class = get_class(files[i])
    

    CORREL_hit = 0
    CHISQR_hit = 0
    INTERSECT_hit = 0
    BHATTACHARYYA_hit = 0
    for f in range(0,len(files),1):
        if (i != f):
            print(files[i], files[f])
            compared_image = cv2.imread(files[f])
            compared_image = cv2.cvtColor(compared_image, cv2.COLOR_BGR2RGB)
            compared_image_class = get_class(files[f])
            
            hist1 = cv2.calcHist([selected_image], [0,1,2], None, [8,8,8], [0,256,0,256,0,256])
            hist2 = cv2.calcHist([compared_image], [0,1,2], None, [8,8,8], [0,256,0,256,0,256])
            cv2.normalize(hist1, hist1, 0, 255, cv2.NORM_MINMAX)
            cv2.normalize(hist2, hist2, 0, 255, cv2.NORM_MINMAX)


            CORREL = cv2.compareHist(hist1, hist2, cv2.HISTCMP_CORREL)
            CHISQR = cv2.compareHist(hist1, hist2, cv2.HISTCMP_CHISQR)
            INTERSECT = cv2.compareHist(hist1, hist2, cv2.HISTCMP_INTERSECT)
            BHATTACHARYYA = cv2.compareHist(hist1, hist2, cv2.HISTCMP_BHATTACHARYYA)
            

            CORREL_hit += verify_hit( class_1 = selected_image_class, class_2 = compared_image_class, value = CORREL, acceptance = CORREL_ACC, higher = True)
            CHISQR_hit += verify_hit( class_1 = selected_image_class, class_2 = compared_image_class, value = CHISQR, acceptance = CHISQR_ACC, higher = False)
            INTERSECT_hit += verify_hit( class_1 = selected_image_class, class_2 = compared_image_class, value = INTERSECT, acceptance = INTERSECT_ACC, higher = True)
            BHATTACHARYYA_hit += verify_hit( class_1 = selected_image_class, class_2 = compared_image_class, value = BHATTACHARYYA, acceptance = BHATTACHARYYA_ACC, higher = False)

            # print("CORREL = ", CORREL)
            print("CHISQR = ", CHISQR)
            # print("INTERSECT = ", INTERSECT)
            # print("BHATTACHARYYA = ", BHATTACHARYYA)
            # print("\n")


    temporary.append(files[i])
    temporary.append(CORREL_hit)
    temporary.append(CHISQR_hit)
    temporary.append(INTERSECT_hit)
    temporary.append(BHATTACHARYYA_hit)
    # print(temporary)

    temp_df = pd.DataFrame(temporary).transpose()
    df = pd.concat([df, temp_df], axis=0, ignore_index=True)


df = df.rename(columns=({0:'IMAGE NAME',
                    1:'CORREL hit',
                    2:'CHISQR hit',
                    3:'INTERSECT hit',
                    4:'BHATTACHARYYA hit'}))

sum_df = pd.DataFrame( [[ 'TOTAL GERAL', sum(df['CORREL hit']), sum(df['CHISQR hit']), sum(df['INTERSECT hit']), sum(df['BHATTACHARYYA hit']) ]], columns=['IMAGE NAME', 'CORREL hit', 'CHISQR hit', 'INTERSECT hit', 'BHATTACHARYYA hit'] )
df = pd.concat([df, sum_df], axis=0, ignore_index=True)

df
# Out:
# hulk1.png hulk2.png
# CHISQR =  4183.6781674384765
# hulk1.png iron1.png
# CHISQR =  9313.780000455312
# hulk1.png iron2.png
# CHISQR =  12116.765262071174
# hulk1.png k3po1.png
# CHISQR =  835.0193602708364
# hulk1.png k3po2.png
# CHISQR =  622.3945422405407
# hulk1.png magneto1.png
# CHISQR =  3482.1329280865584
# hulk1.png magneto2.png
# CHISQR =  3425.1551671704437
# hulk1.png trooper1.png
# CHISQR =  3576.6630659629814
# hulk1.png trooper2.png
# CHISQR =  15319.90152053084
# hulk1.png vader1.png
# CHISQR =  7127.7716925049335
# hulk1.png vader2.png
# CHISQR =  9204.516568979403
# hulk1.png volve1.png
# CHISQR =  1443.862618133968
# hulk1.png volve2.png
# CHISQR =  1318.7586706234108
# hulk2.png hulk1.png
# CHISQR =  2291.213140655601
# hulk2.png iron1.png
# CHISQR =  10550.364278629604
# hulk2.png iron2.png
# CHISQR =  12382.29174411498
# hulk2.png k3po1.png
# CHISQR =  1344.725916654367
# hulk2.png k3po2.png
# CHISQR =  1133.7944239661383
# hulk2.png magneto1.png
# CHISQR =  26772.31114918499
# hulk2.png magneto2.png
# CHISQR =  41855.094403755975
# hulk2.png trooper1.png
# CHISQR =  1604.5498351778006
# hulk2.png trooper2.png
# CHISQR =  5303.332139458856
# hulk2.png vader1.png
# CHISQR =  4703.513110292262
# hulk2.png vader2.png
# CHISQR =  5045.889939663444
# hulk2.png volve1.png
# CHISQR =  1275.849301399836
# hulk2.png volve2.png
# CHISQR =  949.0673602224722
# iron1.png hulk1.png
# CHISQR =  1211.9794198600428
# iron1.png hulk2.png
# CHISQR =  3600.2719986093616
# iron1.png iron2.png
# CHISQR =  2296.532182029179
# iron1.png k3po1.png
# CHISQR =  696.6048777988847
# iron1.png k3po2.png
# CHISQR =  1151.8892626310321
# iron1.png magneto1.png
# CHISQR =  4661.708192629363
# iron1.png magneto2.png
# CHISQR =  8331.566048674695
# iron1.png trooper1.png
# CHISQR =  3046.2229041723376
# iron1.png trooper2.png
# CHISQR =  11563.786285967317
# iron1.png vader1.png
# CHISQR =  5851.686416105468
# iron1.png vader2.png
# CHISQR =  5543.246267895724
# iron1.png volve1.png
# CHISQR =  30001.211637619235
# iron1.png volve2.png
# CHISQR =  66491.89182129197
# iron2.png hulk1.png
# CHISQR =  34335.082102636
# iron2.png hulk2.png
# CHISQR =  39038.55808979926
# iron2.png iron1.png
# CHISQR =  541.8694584680402
# iron2.png k3po1.png
# CHISQR =  873.6963120232684
# iron2.png k3po2.png
# CHISQR =  945.3729485814284
# iron2.png magneto1.png
# CHISQR =  51736.00270260191
# iron2.png magneto2.png
# CHISQR =  74551.0360514945
# iron2.png trooper1.png
# CHISQR =  1169.154642272604
# iron2.png trooper2.png
# CHISQR =  1868.2124749994314
# iron2.png vader1.png
# CHISQR =  7245.57032193738
# iron2.png vader2.png
# CHISQR =  3399.639869814157
# iron2.png volve1.png
# CHISQR =  32503.892883904897
# iron2.png volve2.png
# CHISQR =  8694.12187084357
# k3po1.png hulk1.png
# CHISQR =  5964.244532064789
# k3po1.png hulk2.png
# CHISQR =  25885.996343561834
# k3po1.png iron1.png
# CHISQR =  22083.609482584856
# k3po1.png iron2.png
# CHISQR =  82399.8417001016
# k3po1.png k3po2.png
# CHISQR =  285.6497167088757
# k3po1.png magneto1.png
# CHISQR =  5536.067343516318
# k3po1.png magneto2.png
# CHISQR =  7718.480841154741
# k3po1.png trooper1.png
# CHISQR =  8239.225168810048
# k3po1.png trooper2.png
# CHISQR =  10623.070460362203
# k3po1.png vader1.png
# CHISQR =  23506.37651438586
# k3po1.png vader2.png
# CHISQR =  55662.10886310723
# k3po1.png volve1.png
# CHISQR =  41382.748971529916
# k3po1.png volve2.png
# CHISQR =  31127.76671310554
# k3po2.png hulk1.png
# CHISQR =  8446.59707896468
# k3po2.png hulk2.png
# CHISQR =  31604.954685899185
# k3po2.png iron1.png
# CHISQR =  78257.52297363667
# k3po2.png iron2.png
# CHISQR =  158464.06475187407
# k3po2.png k3po1.png
# CHISQR =  1220.6743736254361
# k3po2.png magneto1.png
# CHISQR =  12901.245138174127
# k3po2.png magneto2.png
# CHISQR =  12967.824174335165
# k3po2.png trooper1.png
# CHISQR =  21943.686182559846
# k3po2.png trooper2.png
# CHISQR =  28490.532456628975
# k3po2.png vader1.png
# CHISQR =  50299.81741964542
# k3po2.png vader2.png
# CHISQR =  88096.42135546931
# k3po2.png volve1.png
# CHISQR =  47624.54109413966
# k3po2.png volve2.png
# CHISQR =  35753.25157394289
# magneto1.png hulk1.png
# CHISQR =  2522.333097323904
# magneto1.png hulk2.png
# CHISQR =  6698.971483559176
# magneto1.png iron1.png
# CHISQR =  19822.501916939116
# magneto1.png iron2.png
# CHISQR =  22562.79448361035
# magneto1.png k3po1.png
# CHISQR =  22526.561276200482
# magneto1.png k3po2.png
# CHISQR =  40763.629132563015
# magneto1.png magneto2.png
# CHISQR =  234.80160907031205
# magneto1.png trooper1.png
# CHISQR =  7070.533972069174
# magneto1.png trooper2.png
# CHISQR =  14761.66676149305
# magneto1.png vader1.png
# CHISQR =  10129.776954282286
# magneto1.png vader2.png
# CHISQR =  17657.1714569868
# magneto1.png volve1.png
# CHISQR =  7829.146616232611
# magneto1.png volve2.png
# CHISQR =  15673.702847629362
# magneto2.png hulk1.png
# CHISQR =  2511.891011502174
# magneto2.png hulk2.png
# CHISQR =  8968.801050393457
# magneto2.png iron1.png
# CHISQR =  12042.622767797116
# magneto2.png iron2.png
# CHISQR =  13593.692731367764
# magneto2.png k3po1.png
# CHISQR =  17793.34177725839
# magneto2.png k3po2.png
# CHISQR =  22193.507764735896
# magneto2.png magneto1.png
# CHISQR =  400.9154417304474
# magneto2.png trooper1.png
# CHISQR =  4659.873590301952
# magneto2.png trooper2.png
# CHISQR =  15307.73556262383
# magneto2.png vader1.png
# CHISQR =  7271.2436550010625
# magneto2.png vader2.png
# CHISQR =  11029.867028318959
# magneto2.png volve1.png
# CHISQR =  5543.182981545986
# magneto2.png volve2.png
# CHISQR =  8345.73131006108
# trooper1.png hulk1.png
# CHISQR =  9395.081310664691
# trooper1.png hulk2.png
# CHISQR =  14500.43103669905
# trooper1.png iron1.png
# CHISQR =  35620.17584491869
# trooper1.png iron2.png
# CHISQR =  91257.58346776133
# trooper1.png k3po1.png
# CHISQR =  11578.793639714244
# trooper1.png k3po2.png
# CHISQR =  46431.325479100626
# trooper1.png magneto1.png
# CHISQR =  115030.94127553122
# trooper1.png magneto2.png
# CHISQR =  219945.47342828652
# trooper1.png trooper2.png
# CHISQR =  1396.095126586821
# trooper1.png vader1.png
# CHISQR =  6120.989129947372
# trooper1.png vader2.png
# CHISQR =  6325.307548963867
# trooper1.png volve1.png
# CHISQR =  6688.958910449371
# trooper1.png volve2.png
# CHISQR =  5340.3060289520545
# trooper2.png hulk1.png
# CHISQR =  4195.210776673235
# trooper2.png hulk2.png
# CHISQR =  1613.8596765340874
# trooper2.png iron1.png
# CHISQR =  17277.928793358216
# trooper2.png iron2.png
# CHISQR =  21512.556401315698
# trooper2.png k3po1.png
# CHISQR =  3926.1169265028257
# trooper2.png k3po2.png
# CHISQR =  6310.736302127531
# trooper2.png magneto1.png
# CHISQR =  82808.105259077
# trooper2.png magneto2.png
# CHISQR =  127763.10753517754
# trooper2.png trooper1.png
# CHISQR =  461.1382094268449
# trooper2.png vader1.png
# CHISQR =  6688.494504237224
# trooper2.png vader2.png
# CHISQR =  7265.471321394733
# trooper2.png volve1.png
# CHISQR =  2986.0782845099875
# trooper2.png volve2.png
# CHISQR =  3518.4212831734026
# vader1.png hulk1.png
# CHISQR =  30845.29692144375
# vader1.png hulk2.png
# CHISQR =  56337.02244825708
# vader1.png iron1.png
# CHISQR =  42968.21482125868
# vader1.png iron2.png
# CHISQR =  50966.686861297625
# vader1.png k3po1.png
# CHISQR =  47990.127033631245
# vader1.png k3po2.png
# CHISQR =  40154.6516802651
# vader1.png magneto1.png
# CHISQR =  89505.00037602834
# vader1.png magneto2.png
# CHISQR =  145018.92741929254
# vader1.png trooper1.png
# CHISQR =  44478.970810230116
# vader1.png trooper2.png
# CHISQR =  76132.43554947554
# vader1.png vader2.png
# CHISQR =  10493.82625409347
# vader1.png volve1.png
# CHISQR =  34303.56474841283
# vader1.png volve2.png
# CHISQR =  42126.10250160796
# vader2.png hulk1.png
# CHISQR =  35452.608795715365
# vader2.png hulk2.png
# CHISQR =  81709.9053062982
# vader2.png iron1.png
# CHISQR =  6286.4237263588375
# vader2.png iron2.png
# CHISQR =  10307.483170905958
# vader2.png k3po1.png
# CHISQR =  10347.082239093981
# vader2.png k3po2.png
# CHISQR =  7751.122109551114
# vader2.png magneto1.png
# CHISQR =  18612.353125473153
# vader2.png magneto2.png
# CHISQR =  16854.270598670275
# vader2.png trooper1.png
# CHISQR =  5582.233920732827
# vader2.png trooper2.png
# CHISQR =  9619.731244147464
# vader2.png vader1.png
# CHISQR =  894.3295559021424
# vader2.png volve1.png
# CHISQR =  10252.266790118249
# vader2.png volve2.png
# CHISQR =  5339.488365426628
# volve1.png hulk1.png
# CHISQR =  2406.3022692466116
# volve1.png hulk2.png
# CHISQR =  4687.878526748108
# volve1.png iron1.png
# CHISQR =  17828.29602128175
# volve1.png iron2.png
# CHISQR =  48009.88207470321
# volve1.png k3po1.png
# CHISQR =  2949.2700754145994
# volve1.png k3po2.png
# CHISQR =  2583.9741476726294
# volve1.png magneto1.png
# CHISQR =  29361.469303410562
# volve1.png magneto2.png
# CHISQR =  47863.072298122934
# volve1.png trooper1.png
# CHISQR =  1744.5823972818787
# volve1.png trooper2.png
# CHISQR =  7439.004182509656
# volve1.png vader1.png
# CHISQR =  3620.139442192114
# volve1.png vader2.png
# CHISQR =  4506.309127027483
# volve1.png volve2.png
# CHISQR =  679.3784657383067
# volve2.png hulk1.png
# CHISQR =  1393.1520824149334
# volve2.png hulk2.png
# CHISQR =  3471.338585393914
# volve2.png iron1.png
# CHISQR =  5295.773388544189
# volve2.png iron2.png
# CHISQR =  5733.6362088303795
# volve2.png k3po1.png
# CHISQR =  2347.987392482315
# volve2.png k3po2.png
# CHISQR =  2199.041170609634
# volve2.png magneto1.png
# CHISQR =  2765.5755623071736
# volve2.png magneto2.png
# CHISQR =  6819.544646728482
# volve2.png trooper1.png
# CHISQR =  1584.5554668634318
# volve2.png trooper2.png
# CHISQR =  6504.8260049373175
# volve2.png vader1.png
# CHISQR =  2886.8834639910456
# volve2.png vader2.png
# CHISQR =  3252.003560628519
# volve2.png volve1.png
# CHISQR =  1509.0429856591604
#       IMAGE NAME CORREL hit CHISQR hit INTERSECT hit BHATTACHARYYA hit
# 0      hulk1.png          1          0             1                 1
# 1      hulk2.png          1          1             1                 1
# 2      iron1.png          1          1             1                 1
# 3      iron2.png          1          1             1                 1
# 4      k3po1.png          1          1             0                 1
# 5      k3po2.png          1          1             0                 1
# 6   magneto1.png          1          1             1                 1
# 7   magneto2.png          1          1             1                 1
# 8   trooper1.png          0          1             1                 1
# 9   trooper2.png          0          1             1                 1
# 10    vader1.png          0          0             0                 0
# 11    vader2.png          0          1             0                 0
# 12    volve1.png          1          1             1                 1
# 13    volve2.png          1          1             1                 1
# 14   TOTAL GERAL         10         12            10                12

# %%
# IMAGENS EM PRETO E BRANCO

df = pd.DataFrame()
for i in range(0,len(files),1):
    temporary = []
    
    selected_image = cv2.imread(files[i],0)
    selected_image_class = get_class(files[i])
    

    CORREL_hit = 0
    CHISQR_hit = 0
    INTERSECT_hit = 0
    BHATTACHARYYA_hit = 0
    for f in range(0,len(files),1):
        if (i != f):
            # print(files[i], files[f])
            compared_image = cv2.imread(files[f],0)
            compared_image_class = get_class(files[f])
            
            hist1 = cv2.calcHist([selected_image], [0], None, [256], [0,256])
            hist2 = cv2.calcHist([compared_image], [0], None, [256], [0,256])
            cv2.normalize(hist1, hist1, 0, 255, cv2.NORM_MINMAX)
            cv2.normalize(hist2, hist2, 0, 255, cv2.NORM_MINMAX)


            CORREL = cv2.compareHist(hist1, hist2, cv2.HISTCMP_CORREL)
            CHISQR = cv2.compareHist(hist1, hist2, cv2.HISTCMP_CHISQR)
            INTERSECT = cv2.compareHist(hist1, hist2, cv2.HISTCMP_INTERSECT)
            BHATTACHARYYA = cv2.compareHist(hist1, hist2, cv2.HISTCMP_BHATTACHARYYA)
            

            CORREL_hit += verify_hit( class_1 = selected_image_class, class_2 = compared_image_class, value = CORREL, acceptance = CORREL_ACC, higher = True)
            CHISQR_hit += verify_hit( class_1 = selected_image_class, class_2 = compared_image_class, value = CHISQR, acceptance = CHISQR_ACC, higher = False)
            INTERSECT_hit += verify_hit( class_1 = selected_image_class, class_2 = compared_image_class, value = INTERSECT, acceptance = INTERSECT_ACC, higher = True)
            BHATTACHARYYA_hit += verify_hit( class_1 = selected_image_class, class_2 = compared_image_class, value = BHATTACHARYYA, acceptance = BHATTACHARYYA_ACC, higher = False)

            # print("CORREL = ", CORREL)
            # print("CHISQR = ", CHISQR)
            # print("INTERSECT = ", INTERSECT)
            # print("BHATTACHARYYA = ", BHATTACHARYYA)
            # print("\n")


    temporary.append(files[i])
    temporary.append(CORREL_hit)
    temporary.append(CHISQR_hit)
    temporary.append(INTERSECT_hit)
    temporary.append(BHATTACHARYYA_hit)
    # print(temporary)

    temp_df = pd.DataFrame(temporary).transpose()
    df = pd.concat([df, temp_df], axis=0, ignore_index=True)


df = df.rename(columns=({0:'IMAGE NAME',
                    1:'CORREL hit',
                    2:'CHISQR hit',
                    3:'INTERSECT hit',
                    4:'BHATTACHARYYA hit'}))

sum_df = pd.DataFrame( [[ 'TOTAL GERAL', sum(df['CORREL hit']), sum(df['CHISQR hit']), sum(df['INTERSECT hit']), sum(df['BHATTACHARYYA hit']) ]], columns=['IMAGE NAME', 'CORREL hit', 'CHISQR hit', 'INTERSECT hit', 'BHATTACHARYYA hit'] )
df = pd.concat([df, sum_df], axis=0, ignore_index=True)
df
# Out:
#       IMAGE NAME CORREL hit CHISQR hit INTERSECT hit BHATTACHARYYA hit
# 0      hulk1.png          0          0             1                 1
# 1      hulk2.png          0          0             1                 1
# 2      iron1.png          0          0             1                 1
# 3      iron2.png          0          0             1                 1
# 4      k3po1.png          1          1             1                 1
# 5      k3po2.png          1          1             1                 1
# 6   magneto1.png          1          1             1                 1
# 7   magneto2.png          1          0             1                 1
# 8   trooper1.png          0          0             1                 1
# 9   trooper2.png          0          0             1                 1
# 10    vader1.png          0          0             0                 0
# 11    vader2.png          0          0             0                 0
# 12    volve1.png          1          0             1                 1
# 13    volve2.png          1          1             1                 1
# 14   TOTAL GERAL          6          4            12                12

# %%
for i in range(0,1,1):
    
    for f in range(0,len(files),1):
        if (i != f):
            print(i,f)

# %%
testes = pd.DataFrame([], columns=['EXAMES DO MÉTODO RT-PCR (por dia)', 'EXAMES DO MÉTODO RT-PCR (por semana)', 'One Step Test', 'Testes de Antígenos (realizados nos últimos 7 dias)'])
testes

# %%
d={"a": 3, "b": 2}
minimo = min(d, key=d.get)
print(minimo)
maximo = max(d, key=d.get)
print(maximo)
# Out:
# b
# a

# %%
# IMAGENS COLORIDAS

df = pd.DataFrame()
for i in range(0,len(files),1):
    temporary = []
    dic_correl = {}
    dic_chisqr = {}
    dic_intersect = {}
    dic_bhattacharyya = {}
    
    selected_image = cv2.imread(files[i])
    selected_image = cv2.cvtColor(selected_image, cv2.COLOR_BGR2RGB)
    selected_image_class = get_class(files[i])
    

    CORREL_hit, correl_max, CHISQR_hit, chisqr_min, INTERSECT_hit, intersect_max, BHATTACHARYYA_hit, bhattacharyya_min = 0, 0, 0, 0, 0, 0, 0, 0
    for f in range(0,len(files),1):
        if (i != f):
            # print(files[i], files[f])
            compared_image = cv2.imread(files[f])
            compared_image = cv2.cvtColor(compared_image, cv2.COLOR_BGR2RGB)
            
            hist1 = cv2.calcHist([selected_image], [0,1,2], None, [8,8,8], [0,256,0,256,0,256])
            hist2 = cv2.calcHist([compared_image], [0,1,2], None, [8,8,8], [0,256,0,256,0,256])
            cv2.normalize(hist1, hist1, 0, 255, cv2.NORM_MINMAX)
            cv2.normalize(hist2, hist2, 0, 255, cv2.NORM_MINMAX)


            CORREL = cv2.compareHist(hist1, hist2, cv2.HISTCMP_CORREL)
            CHISQR = cv2.compareHist(hist1, hist2, cv2.HISTCMP_CHISQR)
            INTERSECT = cv2.compareHist(hist1, hist2, cv2.HISTCMP_INTERSECT)
            BHATTACHARYYA = cv2.compareHist(hist1, hist2, cv2.HISTCMP_BHATTACHARYYA)


            # print("CORREL = ", CORREL)
            # print("CHISQR = ", CHISQR)
            # print("INTERSECT = ", INTERSECT)
            # print("BHATTACHARYYA = ", BHATTACHARYYA)
            # print("\n")
            

            dic_correl[files[f]] = CORREL
            dic_chisqr[files[f]] = CHISQR
            dic_intersect[files[f]] = INTERSECT
            dic_bhattacharyya[files[f]] = BHATTACHARYYA

    
    
    correl_max = max(dic_correl, key=dic_correl.get)
    CORREL_hit = verify( class_1 = selected_image_class, class_2 = get_class(correl_max))


    chisqr_min = min(dic_chisqr, key=dic_chisqr.get)
    CHISQR_hit = verify( class_1 = selected_image_class, class_2 = get_class(chisqr_min))


    intersect_max = max(dic_intersect, key=dic_intersect.get)
    INTERSECT_hit = verify( class_1 = selected_image_class, class_2 = get_class(intersect_max))


    bhattacharyya_min = min(dic_bhattacharyya, key=dic_bhattacharyya.get)
    BHATTACHARYYA_hit = verify( class_1 = selected_image_class, class_2 = get_class(bhattacharyya_min))


    temporary.append(files[i])
    temporary.append(CORREL_hit)
    temporary.append(CHISQR_hit)
    temporary.append(INTERSECT_hit)
    temporary.append(BHATTACHARYYA_hit)
    # print(temporary)

    temp_df = pd.DataFrame(temporary).transpose()
    df = pd.concat([df, temp_df], axis=0, ignore_index=True)


df = df.rename(columns=({0:'IMAGE NAME',
                    1:'CORREL hit',
                    2:'CHISQR hit',
                    3:'INTERSECT hit',
                    4:'BHATTACHARYYA hit'}))

sum_df = pd.DataFrame( [[ 'TOTAL GERAL', sum(df['CORREL hit']), sum(df['CHISQR hit']), sum(df['INTERSECT hit']), sum(df['BHATTACHARYYA hit']) ]], columns=['IMAGE NAME', 'CORREL hit', 'CHISQR hit', 'INTERSECT hit', 'BHATTACHARYYA hit'] )
df = pd.concat([df, sum_df], axis=0, ignore_index=True)

df
# Out:
#       IMAGE NAME CORREL hit CHISQR hit INTERSECT hit BHATTACHARYYA hit
# 0      hulk1.png          1          0             1                 1
# 1      hulk2.png          0          0             0                 1
# 2      iron1.png          0          0             1                 1
# 3      iron2.png          1          1             0                 1
# 4      k3po1.png          1          1             0                 1
# 5      k3po2.png          1          1             0                 1
# 6   magneto1.png          1          1             1                 1
# 7   magneto2.png          1          1             1                 1
# 8   trooper1.png          0          1             1                 1
# 9   trooper2.png          0          1             0                 1
# 10    vader1.png          1          1             1                 1
# 11    vader2.png          1          1             0                 1
# 12    volve1.png          1          1             1                 1
# 13    volve2.png          1          0             1                 1
# 14   TOTAL GERAL         10         10             8                14

# %%
print(dic_correl)
minimo = min(dic_correl, key=dic_correl.get)
print(minimo)
# Out:
# {'hulk2.png': 0.8794585939060866, 'iron1.png': 0.8236188578126534, 'iron2.png': 0.84404566687619, 'k3po1.png': 0.8538218350439268, 'k3po2.png': 0.8576476521614392, 'magneto1.png': 0.8031793918993911, 'magneto2.png': 0.7936642532445187, 'trooper1.png': 0.4560188229789735, 'trooper2.png': 0.6802362543604153, 'vader1.png': 0.037810696314975946, 'vader2.png': 0.36345940307301383, 'volve1.png': 0.7678838964368921, 'volve2.png': 0.8410970119242422}
# vader1.png

# %%
def verify (class_1, class_2):
    if (class_1 == class_2):
        return 1
    else:
        return 0

# %%
compared_image_class = get_class(bhattacharyya_min)
print(compared_image_class)
# Out:
# volve
